# %%
from astroquery.ipac.nexsci.nasa_exoplanet_archive import NasaExoplanetArchive
pl_name = "K2-18 b"
# NasaExoplanetArchive.query_object("K2-18 b")
# NasaExoplanetArchive.query_criteria(table="pscomppars", where=f"pl_name like %{pl_name}%")
NasaExoplanetArchive.query_criteria(

    table="pscomppars", where="hostname like 'Kepler%'", order="hostname")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 pl_name = "K2-18 b"
#       3 # NasaExoplanetArchive.query_object("K2-18 b")
#       4 # NasaExoplanetArchive.query_criteria(table="pscomppars", select="pl_name", where=f"pl_name like %{pl_name}%")
# ----> 5 NasaExoplanetArchive.query_criteria(
#       6
#       7     table="pscomppars", where="hostname like 'Kepler%'", order="hostname")
#
# File ~/Desktop/space-apps/jwst/venv/lib/python3.9/site-packages/astroquery/utils/class_or_instance.py:25, in class_or_instance.__get__.<locals>.f(*args, **kwds)
#      23 def f(*args, **kwds):
#      24     if obj is not None:
# ---> 25         return self.fn(obj, *args, **kwds)
#      26     else:
#      27         return self.fn(cls, *args, **kwds)
#
# ...

# %%
from astroquery.gaia import Gaia
job = Gaia.launch_job_async("select top 100 designation,ra,dec "
                            "from gaiadr3.gaia_source order by source_id")
r = job.get_results()
print(r)
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
#      DESIGNATION               ra                 dec
#                               deg                 deg
# ---------------------- ------------------ --------------------
#    Gaia DR3 4295806720  44.99615537864534 0.005615226341865997
#   Gaia DR3 34361129088  45.00432028915398 0.021047763781174733
#   Gaia DR3 38655544960 45.004978371745516 0.019879675701858644
#  Gaia DR3 309238066432  44.99503714416301  0.03815169755425531
#  Gaia DR3 343597448960  44.96389626549711  0.04359494367771267
#  Gaia DR3 515396233856  44.99832707810714   0.0663327072023917
#  Gaia DR3 549755818112  45.04828232129832  0.04825396034378256
#  Gaia DR3 828929527040  45.02361979732255  0.06841876724959775
#  Gaia DR3 927713095040  45.02672698087207  0.08169947826793385
#  Gaia DR3 966367933184 45.039080477403814  0.08685485276440565
#                    ...                ...                  ...
# ...

# %%
query = f"""
SELECT * FROM gaiadr3.gaia_source limit 10
"""

job = Gaia.launch_job_async(query)
r = job.get_results()
print(r)
# Out:
# 500 Error 500:
# null
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       1 query = f"""
#       2 SELECT * FROM gaiadr3.gaia_source limit 10
#       3 """
# ----> 5 job = Gaia.launch_job_async(query)
#       6 r = job.get_results()
#       7 print(r)
#
# File ~/Desktop/space-apps/jwst/venv/lib/python3.9/site-packages/astroquery/gaia/core.py:1021, in GaiaClass.launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name, autorun)
#     980 def launch_job_async(self, query, *, name=None, output_file=None,
#     981                      output_format="votable_gzip", verbose=False,
#     982                      dump_to_file=False, background=False,
#     983                      upload_resource=None, upload_table_name=None,
#     984                      autorun=True):
# ...
